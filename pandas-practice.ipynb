# %%
import pandas as pd

# %%
coffee = pd.read_csv('warmup-data/coffee.csv')

# %% [markdown]
# Basic Commands

# %%
#coffee.head()
#coffee.tail()
#coffee.describe()
#coffee.columns.to_list()
#coffee.index.to_list()
#coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %% [markdown]
# Acessing Data

# %%
#coffee.loc[0:3, ["Day", "Coffee Type"]]
#coffee.loc[[0, 1, 4], "Units Sold"]
#coffee.iloc[0, 0]
#coffee.iloc[0:4, 0:2]
# Out:
#        Day Coffee Type
# 0   Monday    Espresso
# 1   Monday       Latte
# 2  Tuesday    Espresso
# 3  Tuesday       Latte

# %%
bios = pd.read_csv("data/bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# Filtering Data

# %%
#bios.loc[bios["height_cm"] > 223.0]

#bios.loc[bios["height_cm"] > 200.0][["name", "NOC"]]

#bios.loc[bios["born_country"] == "USA"]

#bios.loc[(bios["height_cm"] > 180.0) & (bios["born_country"] == "FRA")][["name"]]

bios[bios["name"].str.contains("Ronaldo")]
# Out:
#         athlete_id                 name   born_date              born_city  \
# 24023        24210              Ronaldo  1974-02-18             Piracicaba
# 24027        24214              Ronaldo  1976-09-22          Bento Ribeiro
# 24071        24258       Ronaldo Moraes  1962-03-02                Guarujá
# 35548        35827  Ronaldo de Carvalho  1959-10-01         Rio de Janeiro
# 63154        63624       Ronaldo Senfft  1954-07-12         Rio de Janeiro
# 65037        65527     Ronaldo da Costa  1970-06-07             Descoberto
# 66194        66699      Ronaldo Lanzoni  1959-08-21               San José
# 102009      102944    Cristiano Ronaldo  1985-02-05                Funchal
# 144003      147667      Ronaldo Deaconu  1997-05-13  București (Bucharest)
#
#                        born_region born_country         NOC  height_cm  \
# 24023                    São Paulo          BRA      Brazil      186.0
# 24027               Rio de Janeiro          BRA      Brazil      183.0
# ...
